# %%
import warnings
warnings.filterwarnings('ignore')

# Dependencies
import pandas as pd
import requests
import os
import pymongo
import json
from pprint import pprint
# import shapely

# mapbox API Key
from config import (mapbox_api)

# %%
# set end URL for PDX Open Data
query_url = "https://opendata.arcgis.com/datasets/9f50a605cf4945259b983fa35c993fe9_125.geojson"

# %%
response = requests.get(query_url).json()
pprint(response)
# Out:
# {'crs': {'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'},
#          'type': 'name'},
#  'features': [{'geometry': {'coordinates': [[[-122.74774080646131,
#                                               45.57641768898887],
#                                              [-122.74500149910529,
#                                               45.57857491566089],
#                                              [-122.74269522193698,
#                                               45.58047343916037],
#                                              [-122.74104347614936,
#                                               45.581833404649124],
#                                              [-122.73855205350608,
#                                               45.583948080459194],
#                                              [-122.73985832520177,
#                                               45.584275214997184],
#                                              [-122.7395075097271,
# ...

# %%
# coords = response["features"][0]["geometry"]["coordinates"]
# pprint(coords)
coords = []
name = []

for x in response:
    geo = response["features"]["geometry"]["coordinates"]
    reg = response["features"]["properties"]["NAME"]
    coords.append(geo)
    name.append(reg)

name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-50f0c25f9c78> in <module>
#       5
#       6 for x in response:
# ----> 7     geo = response["features"]["geometry"]["coordinates"]
#       8     reg = response["features"]["properties"]["NAME"]
#       9     coords.append(geo)
#
# TypeError: list indices must be integers or slices, not str
